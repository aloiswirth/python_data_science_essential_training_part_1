# %% [markdown]
# # Chapter 5 - Basic Math and Statistics
# ## Segment 7 - Transforming dataset distributions

# %%
import numpy as np
import pandas as pd
import scipy

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

import sklearn
from sklearn import preprocessing
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10, 8
sb.set_style('whitegrid')

# %% [markdown]
# ### Normalizing and transforming features with MinMaxScalar() and fit_transform()

# %%
address = '/home/d022785/SAPDevelop/git_extern/python_data_science_essential_training_part_1/Data/mtcars.csv'

cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

# %%
mpg = cars.mpg
plt.plot(mpg)

# %%
cars[['mpg']].describe()
# Out:
#              mpg
# count  32.000000
# mean   20.090625
# std     6.026948
# min    10.400000
# 25%    15.425000
# 50%    19.200000
# 75%    22.800000
# max    33.900000

# %%
mpg_matrix = mpg.values.reshape(-1, 1)
scaled = preprocessing.MinMaxScaler()

scaled_mpg = scale.fit_transform(mpg_matrix)
plt.plot(scaled_mpg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/d022785/SAPDevelop/git_extern/python_data_science_essential_training_part_1/05_07_begin/05_07_begin.ipynb Cell 8 in <cell line: 4>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/d022785/SAPDevelop/git_extern/python_data_science_essential_training_part_1/05_07_begin/05_07_begin.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> mpg_matrix = mpg.values.reshape(-1, 1)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/d022785/SAPDevelop/git_extern/python_data_science_essential_training_part_1/05_07_begin/05_07_begin.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> scaled = preprocessing.MinMaxScaler()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/d022785/SAPDevelop/git_extern/python_data_science_essential_training_part_1/05_07_begin/05_07_begin.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> scaled_mpg = scale.fit_transform(mpg_matrix)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/d022785/SAPDevelop/git_extern/python_data_science_essential_training_part_1/05_07_begin/05_07_begin.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> plt.plot(scaled_mpg)
#
# AttributeError: 'function' object has no attribute 'fit_transform'

# %%
scaled = preprocessing.MinMaxScaler(feature_range=(0,10))

scaled_mpg = scaled.fit_transform(mpg_matrix)
plt.plot(scaled_mpg)

# %% [markdown]
# ### Using scale() to scale your features

# %%
standardized_mpg = scale(mpg, axis=0, with_mean=False, with_std=False )
plt.plot(standardized_mpg)

# %%
standardized_mpg = scale(mpg )
plt.plot(standardized_mpg)
